# %%
#numbers[numbers > mean]

# %%
import numpy as np

numbers = np.array([10, 50, 30, 80, 20])
mean = np.mean(numbers)  # 38.0

# Step 1: Comparison creates boolean array
mask = numbers > mean
print(mask)  # [False  True False  True False]

# Step 2: Boolean array filters original
result = numbers[mask]
print(result)  # [50 80]

# Usually done in one line:
result = numbers[numbers > mean]
# Out:
# [False  True False  True False]
# [50 80]

# %%
temperatures = np.array([22.5, 25.0, 19.0, 30.5, 27.0, 15.5])

hot_days = temperatures[temperatures > 30.0]
print(f"hot_days (>30.0°C): {hot_days}")  


comfortable = temperatures[(temperatures >= 20.0) & (temperatures <= 30.0)]
print(f"comfortable (20.0-25.0°C): {comfortable}")


cold_days = temperatures[(temperatures < 20.0) | (temperatures > 35.0)]
print(f"cold_days (<20.0°C or >35.0°C): {cold_days}")
# Out:
# hot_days (>30.0°C): [30.5]
# comfortable (20.0-25.0°C): [22.5 25.  27. ]
# cold_days (<20.0°C or >35.0°C): [19.  15.5]
# number of cold days: 2
